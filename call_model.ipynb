# %%
p = '/home/akazemi3/Desktop/Engineered_Model/'
import sys
sys.path.append(p)
from models.model_2L import EngineeredModel2L

# %%
model = EngineeredModel2L(filters_2=1000).Build()

# %%
model
# Out:
# Model(
#   (c1): StandardConvolution(out_channels=None, kernel_size=15, filter_type:curvature,pooling=None,curv_params:{'n_ories': 8, 'n_curves': 3, 'gau_sizes': (5,), 'spatial_fre': [1.2]})
#   (mp1): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   (c2): Conv2d(24, 1000, kernel_size=(9, 9), stride=(1, 1))
#   (mp2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (last): Output()
# )
